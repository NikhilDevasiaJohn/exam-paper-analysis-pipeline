# %% [markdown]
# # 03 — Topic Classification
#
# **Input:** `data/processed/questions.json`
# **Output:** `data/processed/classified_questions.json`
#
# **Purpose:** Classify each question into topics using BART zero-shot.
# Add confidence scores. Flag unclassified.
#
# ---
#
# ⚠️ Run `02_segmentation.ipynb` first.
