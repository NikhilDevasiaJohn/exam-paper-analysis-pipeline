# %% [markdown]
# # 04 — Aggregation & Trend Analysis
#
# **Input:** `data/processed/classified_questions.json`
# **Output:** `data/outputs/report.json`
#
# **Purpose:** Count questions per topic, year-wise breakdown, trend charts.
#
# ---
#
# ⚠️ Run `03_classification.ipynb` first.
